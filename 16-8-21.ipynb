# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
Data=pd.read_csv("Salary_Data.csv",)

# %%
Data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
plt.scatter(Data["YearsExperience"],Data["Salary"])
plt.show()
sns.pairplot(Data)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
sns.regplot(x="YearsExperience",y="Salary",data=Data)
plt.grid()

# %%
Data.nunique()
# Out:
# YearsExperience    28
# Salary             30
# dtype: int64

# %%
Data.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
plt.hist([Data["YearsExperience"],Data["Salary"]],label=['YearsExperience','Salary'])
plt.legend()
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x=Data[["YearsExperience"]]
y=Data["Salary"]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=10)

# %%
ytest.shape
# Out:
# (6,)

# %%
model=LinearRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
xtest
# Out:
#     YearsExperience
# 20              6.8
# 7               3.2
# 5               2.9
# 2               1.5
# 3               2.0
# 21              7.1

# %%
model.coef_
# Out:
# array([9356.86299354])

# %%
model.intercept_
# Out:
# 26089.096632416717

# %%
model.score(xtest,ytest)*100
# Out:
# 98.16423482070253

# %%
ypred=model.predict(xtest)

# %%
ypred
# Out:
# array([89715.76498848, 56031.05821174, 53223.99931368, 40124.39112273,
#        44802.8226195 , 92522.82388655])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
print(np.sqrt(mean_squared_error(ytest,ypred)))
print(mean_absolute_error(ytest,ypred))
print(r2_score(ytest,ypred)*100)
# Out:
# 3128.189594464234
# 2741.2806275420794
# 98.16423482070253

# %%
plt.scatter(ytest,ypred)
plt.show()
sns.regplot(ytest,ypred)
plt.grid()
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data=pd.read_csv("used_cars_data.csv")
data
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
# ...

# %%
l=[]
for i in data["Name"]:
    x=i.split()
    y=x[0]
    l.append(y)
data["Brand"]=pd.Series(l)

# %%
del data["Name"]

# %%
a = data["Fuel_Type"].str.get_dummies()
b = data["Transmission"].str.get_dummies()
c = data["Location"].str.get_dummies()
d = data["Owner_Type"].str.get_dummies()

# %%
Data=pd.concat([data,a,b["Automatic"],c,d],axis=1)

# %%
del [Data["Location"],Data["Fuel_Type"],Data["Transmission"],Data["Owner_Type"]]

# %%
Data.columns
# Out:
# Index(['S.No.', 'Year', 'Kilometers_Driven', 'Mileage', 'Engine', 'Power',
#        'Seats', 'New_Price', 'Price', 'Brand', 'CNG', 'Diesel', 'Electric',
#        'LPG', 'Petrol', 'Automatic', 'Ahmedabad', 'Bangalore', 'Chennai',
#        'Coimbatore', 'Delhi', 'Hyderabad', 'Jaipur', 'Kochi', 'Kolkata',
#        'Mumbai', 'Pune', 'First', 'Fourth & Above', 'Second', 'Third'],
#       dtype='object')

# %%
Data.corrwith(Data["Price"])
# Out:
# S.No.               -0.020275
# Year                 0.305327
# Kilometers_Driven   -0.011493
# Seats                0.052225
# Price                1.000000
# CNG                 -0.051652
# Diesel               0.320645
# Electric             0.005534
# LPG                 -0.025499
# Petrol              -0.309363
# Automatic            0.586025
# Ahmedabad           -0.017964
# Bangalore            0.086526
# Chennai             -0.046130
# Coimbatore           0.172026
# Delhi                0.006496
# Hyderabad            0.009958
# Jaipur              -0.089049
# Kochi                0.052911
# Kolkata             -0.106606
# Mumbai              -0.001742
# Pune                -0.083550
# First                0.091808
# Fourth & Above      -0.021445
# Second              -0.073552
# Third               -0.055297
# dtype: float64

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 31 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Year               7253 non-null   int64
#  2   Kilometers_Driven  7253 non-null   int64
#  3   Mileage            7251 non-null   object
#  4   Engine             7207 non-null   object
#  5   Power              7207 non-null   object
#  6   Seats              7200 non-null   float64
#  7   New_Price          1006 non-null   object
#  8   Price              6019 non-null   float64
#  9   Brand              7253 non-null   object
#  10  CNG                7253 non-null   int64
#  11  Diesel             7253 non-null   int64
#  12  Electric           7253 non-null   int64
#  13  LPG                7253 non-null   int64
#  14  Petrol             7253 non-null   int64
#  15  Automatic          7253 non-null   int64
# ...

# %%
Data.describe()
# Out:
#              S.No.         Year  Kilometers_Driven        Seats        Price  \
# count  7253.000000  7253.000000       7.253000e+03  7200.000000  6019.000000
# mean   3626.000000  2013.365366       5.869906e+04     5.279722     9.479468
# std    2093.905084     3.254421       8.442772e+04     0.811660    11.187917
# min       0.000000  1996.000000       1.710000e+02     0.000000     0.440000
# 25%    1813.000000  2011.000000       3.400000e+04     5.000000     3.500000
# 50%    3626.000000  2014.000000       5.341600e+04     5.000000     5.640000
# 75%    5439.000000  2016.000000       7.300000e+04     5.000000     9.950000
# max    7252.000000  2019.000000       6.500000e+06    10.000000   160.000000
#
#                CNG       Diesel     Electric          LPG       Petrol  ...  \
# count  7253.000000  7253.000000  7253.000000  7253.000000  7253.000000  ...
# mean      0.008548     0.531091     0.000276     0.001654     0.458431  ...
# ...

# %%
Data
# Out:
#       S.No.  Year  Kilometers_Driven     Mileage   Engine      Power  Seats  \
# 0         0  2010              72000  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1         1  2015              41000  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2         2  2011              46000   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3         3  2012              87000  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4         4  2013              40670   15.2 kmpl  1968 CC  140.8 bhp    5.0
# ...     ...   ...                ...         ...      ...        ...    ...
# 7248   7248  2011              89411  20.54 kmpl  1598 CC  103.6 bhp    5.0
# 7249   7249  2015              59000  17.21 kmpl  1197 CC  103.6 bhp    5.0
# 7250   7250  2012              28000  23.08 kmpl  1461 CC   63.1 bhp    5.0
# 7251   7251  2013              52262   17.2 kmpl  1197 CC  103.6 bhp    5.0
# 7252   7252  2014              72443   10.0 kmpl  2148 CC    170 bhp    5.0
#
# ...

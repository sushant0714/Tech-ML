# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("cruise_ship_info.csv")

# %%
df
# Out:
#        Ship_name Cruise_line  Age  Tonnage  passengers  length  cabins  \
# 0        Journey     Azamara    6   30.277        6.94    5.94    3.55
# 1          Quest     Azamara    6   30.277        6.94    5.94    3.55
# 2    Celebration    Carnival   26   47.262       14.86    7.22    7.43
# 3       Conquest    Carnival   11  110.000       29.74    9.53   14.88
# 4        Destiny    Carnival   17  101.353       26.42    8.92   13.21
# ..           ...         ...  ...      ...         ...     ...     ...
# 153       Taurus        Star   22    3.341        0.66    2.79    0.33
# 154        Virgo        Star   14   76.800       19.60    8.79    9.67
# 155       Spirit    Windstar   25    5.350        1.58    4.40    0.74
# 156         Star    Windstar   27    5.350        1.67    4.40    0.74
# 157         Surf    Windstar   23   14.745        3.08    6.17    1.56
#
#      passenger_density   crew
# 0                42.64   3.55
# 1                42.64   3.55
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ship_name          158 non-null    object
#  1   Cruise_line        158 non-null    object
#  2   Age                158 non-null    int64
#  3   Tonnage            158 non-null    float64
#  4   passengers         158 non-null    float64
#  5   length             158 non-null    float64
#  6   cabins             158 non-null    float64
#  7   passenger_density  158 non-null    float64
#  8   crew               158 non-null    float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 11.2+ KB

# %%
df.describe()
# Out:
#               Age     Tonnage  passengers      length      cabins  \
# count  158.000000  158.000000  158.000000  158.000000  158.000000
# mean    15.689873   71.284671   18.457405    8.130633    8.830000
# std      7.615691   37.229540    9.677095    1.793474    4.471417
# min      4.000000    2.329000    0.660000    2.790000    0.330000
# 25%     10.000000   46.013000   12.535000    7.100000    6.132500
# 50%     14.000000   71.899000   19.500000    8.555000    9.570000
# 75%     20.000000   90.772500   24.845000    9.510000   10.885000
# max     48.000000  220.000000   54.000000   11.820000   27.000000
#
#        passenger_density        crew
# count         158.000000  158.000000
# mean           39.900949    7.794177
# std             8.639217    3.503487
# min            17.700000    0.590000
# 25%            34.570000    5.480000
# 50%            39.085000    8.150000
# 75%            44.185000    9.990000
# max            71.430000   21.000000

# %%
df.isnull().sum()
# Out:
# Ship_name            0
# Cruise_line          0
# Age                  0
# Tonnage              0
# passengers           0
# length               0
# cabins               0
# passenger_density    0
# crew                 0
# dtype: int64

# %%
df.corr()
# Out:
#                         Age   Tonnage  passengers    length    cabins  \
# Age                1.000000 -0.606646   -0.515542 -0.532286 -0.510019
# Tonnage           -0.606646  1.000000    0.945061  0.922368  0.948764
# passengers        -0.515542  0.945061    1.000000  0.883535  0.976341
# length            -0.532286  0.922368    0.883535  1.000000  0.889798
# cabins            -0.510019  0.948764    0.976341  0.889798  1.000000
# passenger_density -0.278830 -0.040846   -0.294867 -0.090488 -0.253181
# crew              -0.530657  0.927569    0.915234  0.895857  0.950823
#
#                    passenger_density      crew
# Age                        -0.278830 -0.530657
# Tonnage                    -0.040846  0.927569
# passengers                 -0.294867  0.915234
# length                     -0.090488  0.895857
# cabins                     -0.253181  0.950823
# passenger_density           1.000000 -0.155509
# crew                       -0.155509  1.000000

# %%
df.columns
# Out:
# Index(['Ship_name', 'Cruise_line', 'Age', 'Tonnage', 'passengers', 'length',
#        'cabins', 'passenger_density', 'crew'],
#       dtype='object')

# %%
df.groupby('Ship_name').describe().T
# Out:
# Ship_name                Adventure  Allegra  Amsterdam  Arcadia   Aries  \
# Age               count       1.00     1.00       1.00     1.00   1.000
#                   mean       12.00    21.00      13.00     9.00  22.000
#                   std          NaN      NaN        NaN      NaN     NaN
#                   min        12.00    21.00      13.00     9.00  22.000
#                   25%        12.00    21.00      13.00     9.00  22.000
#                   50%        12.00    21.00      13.00     9.00  22.000
#                   75%        12.00    21.00      13.00     9.00  22.000
#                   max        12.00    21.00      13.00     9.00  22.000
# Tonnage           count       1.00     1.00       1.00     1.00   1.000
#                   mean      138.00    28.43      61.00    85.00   3.341
#                   std          NaN      NaN        NaN      NaN     NaN
#                   min       138.00    28.43      61.00    85.00   3.341
# ...

# %%
df['Ship_name'].unique()
# Out:
# array(['Journey', 'Quest', 'Celebration', 'Conquest', 'Destiny',
#        'Ecstasy', 'Elation', 'Fantasy', 'Fascination', 'Freedom', 'Glory',
#        'Holiday', 'Imagination', 'Inspiration', 'Legend', 'Liberty*',
#        'Miracle', 'Paradise', 'Pride', 'Sensation', 'Spirit', 'Triumph',
#        'Valor', 'Victory', 'Century', 'Constellation', 'Galaxy',
#        'Infinity', 'Mercury', 'Millenium', 'Solstice', 'Summit',
#        'Xpedition', 'Zenith', 'Allegra', 'Atlantica', 'Classica',
#        'Europa', 'Fortuna', 'Magica', 'Marina', 'Mediterranea',
#        'Romantica', 'Serena', 'Victoria', 'Serenity', 'Symphony',
#        'QueenElizabethII', 'QueenMary2', 'QueenVictoria', 'Magic',
#        'Wonder', 'Amsterdam', 'Eurodam', 'Maasdam', 'Noordam',
#        'Oosterdam', 'Prinsendam', 'Rotterdam', 'Ryndam', 'Statendam',
#        'Veendam', 'Volendam', 'Westerdam', 'Zaandam', 'Zuiderdam',
#        'Armonia', 'Fantasia', 'Lirica', 'Melody', 'Musica', 'Opera',
# ...

# %%
df['Ship_name'].nunique()
# Out:
# 138

# %%
df['Cruise_line'].nunique()
# Out:
# 20

# %%
df.groupby('Cruise_line').describe().T
# Out:
# Cruise_line              Azamara    Carnival   Celebrity       Costa  \
# Age               count    2.000   22.000000   10.000000   11.000000
#                   mean     6.000   15.227273   13.700000   16.181818
#                   std      0.000    5.943639    4.473378    6.911124
#                   min      6.000    6.000000    5.000000    6.000000
#                   25%      6.000   11.000000   12.000000   10.000000
#                   50%      6.000   14.500000   12.500000   17.000000
#                   75%      6.000   18.750000   16.750000   21.500000
#                   max      6.000   28.000000   21.000000   27.000000
# Tonnage           count    2.000   22.000000   10.000000   11.000000
#                   mean    30.277   84.652727   76.158600   71.096545
#                   std      0.000   20.282199   32.156094   30.527773
#                   min     30.277   46.052000    2.329000   25.000000
#                   25%     30.277   70.367000   72.382750   52.987500
# ...

# %%
df
# Out:
#        Ship_name Cruise_line  Age  Tonnage  passengers  length  cabins  \
# 0        Journey     Azamara    6   30.277        6.94    5.94    3.55
# 1          Quest     Azamara    6   30.277        6.94    5.94    3.55
# 2    Celebration    Carnival   26   47.262       14.86    7.22    7.43
# 3       Conquest    Carnival   11  110.000       29.74    9.53   14.88
# 4        Destiny    Carnival   17  101.353       26.42    8.92   13.21
# ..           ...         ...  ...      ...         ...     ...     ...
# 153       Taurus        Star   22    3.341        0.66    2.79    0.33
# 154        Virgo        Star   14   76.800       19.60    8.79    9.67
# 155       Spirit    Windstar   25    5.350        1.58    4.40    0.74
# 156         Star    Windstar   27    5.350        1.67    4.40    0.74
# 157         Surf    Windstar   23   14.745        3.08    6.17    1.56
#
#      passenger_density   crew
# 0                42.64   3.55
# 1                42.64   3.55
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df["Cruise_line"]=le.fit_transform(df["Cruise_line"])
df["Ship_name"]=le.fit_transform(df["Ship_name"])

# %%
df
# Out:
#      Ship_name  Cruise_line  Age  Tonnage  passengers  length  cabins  \
# 0           52            0    6   30.277        6.94    5.94    3.55
# 1           91            0    6   30.277        6.94    5.94    3.55
# 2           11            1   26   47.262       14.86    7.22    7.43
# 3           15            1   11  110.000       29.74    9.53   14.88
# 4           20            1   17  101.353       26.42    8.92   13.21
# ..         ...          ...  ...      ...         ...     ...     ...
# 153        119           18   22    3.341        0.66    2.79    0.33
# 154        126           18   14   76.800       19.60    8.79    9.67
# 155        110           19   25    5.350        1.58    4.40    0.74
# 156        112           19   27    5.350        1.67    4.40    0.74
# 157        116           19   23   14.745        3.08    6.17    1.56
#
#      passenger_density   crew
# 0                42.64   3.55
# 1                42.64   3.55
# 2                31.80   6.70
# ...

# %%
for i in df.columns[:-1]:
    df[i].plot.kde()
    plt.xlabel(i)
    plt.show()

# %%
import seaborn as sns
sns.pairplot(df)

# %%
df.drop(columns=['Ship_name'])
# Out:
#      Cruise_line  Age  Tonnage  passengers  length  cabins  passenger_density  \
# 0              0    6   30.277        6.94    5.94    3.55              42.64
# 1              0    6   30.277        6.94    5.94    3.55              42.64
# 2              1   26   47.262       14.86    7.22    7.43              31.80
# 3              1   11  110.000       29.74    9.53   14.88              36.99
# 4              1   17  101.353       26.42    8.92   13.21              38.36
# ..           ...  ...      ...         ...     ...     ...                ...
# 153           18   22    3.341        0.66    2.79    0.33              50.62
# 154           18   14   76.800       19.60    8.79    9.67              39.18
# 155           19   25    5.350        1.58    4.40    0.74              33.86
# 156           19   27    5.350        1.67    4.40    0.74              32.04
# 157           19   23   14.745        3.08    6.17    1.56              47.87
#
#       crew
# 0     3.55
# ...

# %%
x=df["Cruise_line"]
y=df["crew"]

# %%
x
# Out:
# 0       0
# 1       0
# 2       1
# 3       1
# 4       1
#        ..
# 153    18
# 154    18
# 155    19
# 156    19
# 157    19
# Name: Cruise_line, Length: 158, dtype: int64

# %%
y
# Out:
# 0       3.55
# 1       3.55
# 2       6.70
# 3      19.10
# 4      10.00
#        ...
# 153     0.59
# 154    12.00
# 155     0.88
# 156     0.88
# 157     1.80
# Name: crew, Length: 158, dtype: float64

# %%
plt.scatter(x,y)

# %%
from sklearn.model_selection import train_test_split
X=df.drop(columns=["crew"])

# %%
X
# Out:
#      Ship_name  Cruise_line  Age  Tonnage  passengers  length  cabins  \
# 0           52            0    6   30.277        6.94    5.94    3.55
# 1           91            0    6   30.277        6.94    5.94    3.55
# 2           11            1   26   47.262       14.86    7.22    7.43
# 3           15            1   11  110.000       29.74    9.53   14.88
# 4           20            1   17  101.353       26.42    8.92   13.21
# ..         ...          ...  ...      ...         ...     ...     ...
# 153        119           18   22    3.341        0.66    2.79    0.33
# 154        126           18   14   76.800       19.60    8.79    9.67
# 155        110           19   25    5.350        1.58    4.40    0.74
# 156        112           19   27    5.350        1.67    4.40    0.74
# 157        116           19   23   14.745        3.08    6.17    1.56
#
#      passenger_density
# 0                42.64
# 1                42.64
# 2                31.80
# 3                36.99
# ...

# %%
Y=df["crew"]

# %%
Y
# Out:
# 0       3.55
# 1       3.55
# 2       6.70
# 3      19.10
# 4      10.00
#        ...
# 153     0.59
# 154    12.00
# 155     0.88
# 156     0.88
# 157     1.80
# Name: crew, Length: 158, dtype: float64

# %%
X.corrwith(Y)
# Out:
# Ship_name           -0.201143
# Cruise_line         -0.211687
# Age                 -0.530657
# Tonnage              0.927569
# passengers           0.915234
# length               0.895857
# cabins               0.950823
# passenger_density   -0.155509
# dtype: float64

# %%
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.25,random_state=100)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([-0.00199324, -0.03926601, -0.00883745,  0.02163654, -0.14955333,
#         0.21798903,  0.79494254, -0.00144135])

# %%
lr.score(xtest,ytest)*100
# Out:
# 92.20993109303085

# %%
ypred=lr.predict(xtest)

# %%
ypred
# Out:
# array([ 6.27135372,  6.62724181, 13.70779295, 12.41968953,  8.94458333,
#         3.58704486,  5.14066565,  4.30464522, 11.44919613,  8.4094503 ,
#         9.17435486,  7.13221763,  8.6800175 ,  9.25720661, 11.22096453,
#         3.79727239,  9.65852978,  4.17809955,  6.06893827,  8.0619499 ,
#         6.13676455,  1.29181415,  8.61327872,  2.54310086,  5.45483609,
#         2.06040383,  5.88548063,  9.67393971,  8.64077688, 10.37921368,
#         8.42193532,  7.32752231, 10.95249528, 14.9733178 ,  8.95484846,
#         9.82987159,  6.77653866,  7.82370953,  8.58894717,  2.7322153 ])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
print(np.sqrt(mean_squared_error(ytest,ypred)))
print(mean_absolute_error(ytest,ypred))
lr_score=print(r2_score(ytest,ypred)*100)
# Out:
# 0.889261959873196
# 0.5960815679787913
# 92.20993109303085

# %% [markdown]
# The algorithm we have used in this dataset is "Linear Regression" as the crew members is not categorical data. We just have to predict the number of crew members. Linear Regression is best algo to predict models that shows linear relationship.
